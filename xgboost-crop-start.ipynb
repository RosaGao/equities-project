# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from zipfile import ZipFile
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('selected_factor_and_return.csv')
df.set_index(['date'], inplace=True)

if "Unnamed: 0" in df.columns:
  df.drop("Unnamed: 0", axis=1, inplace=True)

df.head()
# Out:
#             Ticker      Size  Liquidity   cpv_1mo  mr_1yr     mr_1w  \
# date
# 2005-03-02  4151.T  0.603338  -0.370407       NaN     NaN -1.381918
# 2005-03-03  4151.T  0.603338  -0.370407  0.426358     NaN -0.462423
# 2005-03-04  4151.T  0.603338  -0.370407 -1.005234     NaN -1.477961
# 2005-03-07  4151.T  0.603338  -0.370407 -0.731422     NaN -0.398283
# 2005-03-08  4151.T  0.603338  -0.370407 -1.081762     NaN -1.433256
#
#             daily_return
# date
# 2005-03-02     -0.007344
# 2005-03-03      0.016029
# 2005-03-04     -0.001213
# 2005-03-07      0.001215
# 2005-03-08      0.002427

# %%
df.tail()
# Out:
#             Ticker      Size  Liquidity   cpv_1mo    mr_1yr     mr_1w  \
# date
# 2024-02-22  4887.T  0.052614   0.312916 -0.967226 -1.227663  1.173214
# 2024-02-26  4887.T  0.052614   0.312916 -1.061441 -1.209116 -0.017219
# 2024-02-27  4887.T  0.052614   0.312916 -1.163607 -1.202994 -0.882076
# 2024-02-28  4887.T  0.052614   0.312916 -1.065248 -1.200425  1.144204
# 2024-02-29  4887.T  0.052614   0.312916 -1.059960 -1.204539  1.191659
#
#             daily_return
# date
# 2024-02-22     -0.003213
# 2024-02-26     -0.012723
# 2024-02-27     -0.010309
# 2024-02-28     -0.001042
# 2024-02-29     -0.001738

# %%
stocks = df.groupby('Ticker')
stocks.get_group('4151.T')
# Out:
#             Ticker      Size  Liquidity   cpv_1mo    mr_1yr     mr_1w  \
# date
# 2005-03-02  4151.T  0.603338  -0.370407       NaN       NaN -1.381918
# 2005-03-03  4151.T  0.603338  -0.370407  0.426358       NaN -0.462423
# 2005-03-04  4151.T  0.603338  -0.370407 -1.005234       NaN -1.477961
# 2005-03-07  4151.T  0.603338  -0.370407 -0.731422       NaN -0.398283
# 2005-03-08  4151.T  0.603338  -0.370407 -1.081762       NaN -1.433256
# ...            ...       ...        ...       ...       ...       ...
# 2024-02-22  4151.T  0.966493  -0.491249 -1.148382  0.410803 -1.428353
# 2024-02-26  4151.T  0.966493  -0.491249 -1.182013  0.432673 -0.596683
# 2024-02-27  4151.T  0.966493  -0.491249 -1.186365  0.359380 -0.191890
# 2024-02-28  4151.T  0.966493  -0.491249 -1.145645  0.321218 -1.279284
# 2024-02-29  4151.T  0.966493  -0.491249 -1.152495  0.194885 -0.864684
#
#             daily_return
# date
# 2005-03-02     -0.007344
# 2005-03-03      0.016029
# 2005-03-04     -0.001213
# 2005-03-07      0.001215
# 2005-03-08      0.002427
# ...                  ...
# 2024-02-22     -0.001910
# 2024-02-26      0.014962
# 2024-02-27      0.010970
# 2024-02-28      0.000170
# 2024-02-29      0.007459
#
# [4695 rows x 7 columns]

# %%
# get list of features and target column
features_cols = df.columns[1:-1]
target_col = df.columns[-1]

# %%
target = df[target_col]
has_nan = target.isnull().values.any()
print("Contains NaN:", has_nan)

has_inf = target.isin([np.inf, -np.inf]).values.any()
print("Contains infinite values:", has_inf)
# Out:
# Contains NaN: False
# Contains infinite values: False

# %%
mean_ret = target.mean()
df[target_col].fillna(mean_ret, inplace=True)
has_nan = target.isnull().values.any()
print("Contains NaN:", has_nan)
# Out:
# Contains NaN: False

# %%
# # scale ret by 100 for better precision
# df[target_col] = df[target_col] * 100 
# df

# %%
train_start = df.index.unique()[int(len(df.index.unique()) * 0.5)]
train_start
# Out:
# '2014-08-20'

# %%
train_end = df.index.unique()[int(len(df.index.unique()) * 0.9)]
train_end
# Out:
# '2022-03-31'

# %%
val_end = df.index.unique()[int(len(df.index.unique()) * 0.95)]
val_end
# Out:
# '2023-03-16'

# %%
train_df  = df[df.index <= train_end].copy()
valid_df  = df[(df.index > train_end) & (df.index <= val_end)].copy()
test_df   = df[df.index > val_end].copy()

test_df.tail()
# Out:
#             Ticker      Size  Liquidity   cpv_1mo    mr_1yr     mr_1w  \
# date
# 2024-02-22  4887.T  0.052614   0.312916 -0.967226 -1.227663  1.173214
# 2024-02-26  4887.T  0.052614   0.312916 -1.061441 -1.209116 -0.017219
# 2024-02-27  4887.T  0.052614   0.312916 -1.163607 -1.202994 -0.882076
# 2024-02-28  4887.T  0.052614   0.312916 -1.065248 -1.200425  1.144204
# 2024-02-29  4887.T  0.052614   0.312916 -1.059960 -1.204539  1.191659
#
#             daily_return
# date
# 2024-02-22     -0.003213
# 2024-02-26     -0.012723
# 2024-02-27     -0.010309
# 2024-02-28     -0.001042
# 2024-02-29     -0.001738

# %%
valid_date = valid_df.index
valid_ticker = valid_df.Ticker
valid_date
# valid_ticker
# Out:
# Index(['2022-04-01', '2022-04-04', '2022-04-05', '2022-04-06', '2022-04-07',
#        '2022-04-08', '2022-04-11', '2022-04-12', '2022-04-13', '2022-04-14',
#        ...
#        '2023-03-03', '2023-03-06', '2023-03-07', '2023-03-08', '2023-03-09',
#        '2023-03-10', '2023-03-13', '2023-03-14', '2023-03-15', '2023-03-16'],
#       dtype='object', name='date', length=8695)

# %%
test_df

test_date = test_df.index
test_ticker = test_df.Ticker
test_date
test_ticker
# Out:
# date
# 2023-03-17    4151.T
# 2023-03-20    4151.T
# 2023-03-22    4151.T
# 2023-03-23    4151.T
# 2023-03-24    4151.T
#                ...
# 2024-02-22    4887.T
# 2024-02-26    4887.T
# 2024-02-27    4887.T
# 2024-02-28    4887.T
# 2024-02-29    4887.T
# Name: Ticker, Length: 8734, dtype: object

# %%
train_df.drop(columns=['Ticker'], inplace=True)
train_df.tail()
train_df.isnull().sum()
# Out:
# Size               0
# Liquidity          0
# cpv_1mo         3244
# mr_1yr          5064
# mr_1w              0
# daily_return       0
# dtype: int64

# %%
for col in train_df.columns:
  train_df[col].fillna(0, inplace=True)
train_df.isnull().sum()
# Out:
# Size            0
# Liquidity       0
# cpv_1mo         0
# mr_1yr          0
# mr_1w           0
# daily_return    0
# dtype: int64

# %%
if 'Ticker' in test_df.columns:
  test_df.drop(columns=['Ticker'], inplace=True)

for col in test_df.columns:
  test_df[col].fillna(0, inplace=True)
test_df.isnull().sum()
# Out:
# Size            0
# Liquidity       0
# cpv_1mo         0
# mr_1yr          0
# mr_1w           0
# daily_return    0
# dtype: int64

# %%
if 'Ticker' in valid_df.columns:
  valid_df.drop(columns=['Ticker'], inplace=True)

for col in valid_df.columns:
  valid_df[col].fillna(valid_df[col].mean(), inplace=True)
valid_df.isnull().sum()
# Out:
# Size            0
# Liquidity       0
# cpv_1mo         0
# mr_1yr          0
# mr_1w           0
# daily_return    0
# dtype: int64

# %%
target_col
# Out:
# 'daily_return'

# %%
y_train = train_df[target_col].copy()
X_train = train_df.drop([target_col], 1)

y_valid = valid_df[target_col].copy()
X_valid = valid_df.drop([target_col], 1)

y_test  = test_df[target_col].copy()
X_test  = test_df.drop([target_col], 1)

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133275 entries, 2005-03-02 to 2022-03-31
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Size       133275 non-null  float64
#  1   Liquidity  133275 non-null  float64
#  2   cpv_1mo    133275 non-null  float64
#  3   mr_1yr     133275 non-null  float64
#  4   mr_1w      133275 non-null  float64
# dtypes: float64(5)
# memory usage: 6.1+ MB

# %% [markdown]
# The stock returns in the following two days are split to two target variables.

# %%
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
# %%time

parameters = {
    'n_estimators': [100, 200, 300, 400],
    'learning_rate': [0.001, 0.005, 0.01, 0.05],
    'max_depth': [8, 10, 12, 15],
    'gamma': [0.001, 0.005, 0.01, 0.02],
    'random_state': [42]
}

eval_set = [(X_train, y_train), (X_valid, y_valid)]
model = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror', verbose=False)
clf = GridSearchCV(model, parameters)

clf.fit(X_train, y_train)

print(f'Best params: {clf.best_params_}')
print(f'Best validation score = {clf.best_score_}')
# Out:
# Best params: {'gamma': 0.001, 'learning_rate': 0.001, 'max_depth': 8, 'n_estimators': 400, 'random_state': 42}
# Best validation score = 0.0010047074466094097
# CPU times: user 1h 35min 29s, sys: 8min 28s, total: 1h 43min 58s
# Wall time: 15min 23s

# %%
# %%time

model = xgb.XGBRegressor(**clf.best_params_, objective='reg:squarederror')
model.fit(X_train, y_train, eval_set=eval_set, verbose=False)
# Out:
# CPU times: user 27.2 s, sys: 2.61 s, total: 29.8 s
# Wall time: 5.15 s
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.001, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=400, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
plot_importance(model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
y_pred = model.predict(X_test)
print(f'y_true = {np.array(y_test)}')
print(f'y_pred = {y_pred}')
# Out:
# y_true = [ 0.02234036 -0.02393333  0.01137168 ... -0.01030932 -0.00104161
#  -0.001738  ]
# y_pred = [ 0.00046511  0.00037698  0.00037698 ... -0.00024486  0.0003854
#   0.0003854 ]

# %%
y_pred
# Out:
# array([ 0.00046511,  0.00037698,  0.00037698, ..., -0.00024486,
#         0.0003854 ,  0.0003854 ], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error

print(f'mean_squared_error = {mean_squared_error(y_test, y_pred)}')
# Out:
# mean_squared_error = 0.0003232146640077722

# %%
pred_date_df = pd.DataFrame(test_date.to_list()).rename(columns={0: 'date'})
pred_ticker_df = pd.DataFrame(test_ticker).reset_index(drop=True)
y_pred_df = pd.DataFrame(y_pred).rename(columns={0: 'prediction'})

# %%
pred_df = pd.concat([pred_date_df, pred_ticker_df, y_pred_df], axis=1)
pred_df
# Out:
#             date  Ticker  prediction
# 0     2023-03-17  4151.T    0.000465
# 1     2023-03-20  4151.T    0.000377
# 2     2023-03-22  4151.T    0.000377
# 3     2023-03-23  4151.T    0.000401
# 4     2023-03-24  4151.T    0.000414
# ...          ...     ...         ...
# 8729  2024-02-22  4887.T    0.000677
# 8730  2024-02-26  4887.T    0.000361
# 8731  2024-02-27  4887.T   -0.000245
# 8732  2024-02-28  4887.T    0.000385
# 8733  2024-02-29  4887.T    0.000385
#
# [8734 rows x 3 columns]

# %%
excel_file_path = "xgboost_pred-crop.xlsx"

pred_df.to_excel(excel_file_path, index=False)

# %%
valid_y_pred = model.predict(X_valid)
print(f'y_true = {np.array(y_valid)}')
print(f'y_pred = {valid_y_pred}')
# Out:
# y_true = [-0.01264055  0.02773822 -0.02318334 ... -0.02670224  0.00411524
#  -0.01229518]
# y_pred = [0.00048657 0.00054283 0.00053275 ... 0.00039906 0.00061311 0.00039725]

# %%
valid_pred_date_df = pd.DataFrame(valid_date.to_list()).rename(columns={0: 'date'})
valid_pred_ticker_df = pd.DataFrame(valid_ticker).reset_index(drop=True)
valid_y_pred_df = pd.DataFrame(valid_y_pred).rename(columns={0: 'prediction'})

# %%
valid_pred_df = pd.concat([valid_pred_date_df, valid_pred_ticker_df, valid_y_pred_df], axis=1)
valid_pred_df
# Out:
#             date  Ticker  prediction
# 0     2022-04-01  4151.T    0.000487
# 1     2022-04-04  4151.T    0.000543
# 2     2022-04-05  4151.T    0.000533
# 3     2022-04-06  4151.T    0.000540
# 4     2022-04-07  4151.T    0.000540
# ...          ...     ...         ...
# 8690  2023-03-10  4887.T    0.001154
# 8691  2023-03-13  4887.T    0.000326
# 8692  2023-03-14  4887.T    0.000399
# 8693  2023-03-15  4887.T    0.000613
# 8694  2023-03-16  4887.T    0.000397
#
# [8695 rows x 3 columns]

# %%
excel_file_path = "xgboost_validation_pred-crop.xlsx"

valid_pred_df.to_excel(excel_file_path, index=False)
